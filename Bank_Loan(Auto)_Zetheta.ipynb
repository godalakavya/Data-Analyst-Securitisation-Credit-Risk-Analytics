# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
file_path = os.path.expanduser("~/Desktop/auto_loan_securitisation_data.csv")
df = pd.read_csv(file_path)
df
# Out:
#                  LoanID        PoolID  BorrowerID ServicerID  \
# 0    ZAAUTO2024-1-00001  ZAAUTO2024-1  BOR-131244     SVC001
# 1    ZAAUTO2024-1-00002  ZAAUTO2024-1  BOR-748564     SVC003
# 2    ZAAUTO2024-1-00003  ZAAUTO2024-1  BOR-694731     SVC002
# 3    ZAAUTO2024-1-00004  ZAAUTO2024-1  BOR-855731     SVC003
# 4    ZAAUTO2024-1-00005  ZAAUTO2024-1  BOR-897549     SVC003
# ..                  ...           ...         ...        ...
# 495  ZAAUTO2024-1-00496  ZAAUTO2024-1  BOR-130294     SVC002
# 496  ZAAUTO2024-1-00497  ZAAUTO2024-1  BOR-208691     SVC003
# 497  ZAAUTO2024-1-00498  ZAAUTO2024-1  BOR-375903     SVC002
# 498  ZAAUTO2024-1-00499  ZAAUTO2024-1  BOR-366825     SVC003
# 499  ZAAUTO2024-1-00500  ZAAUTO2024-1  BOR-597793     SVC003
#
#                ServicerName OriginationChannel OriginationDate  CutoffDate  \
# 0    HDFC Bank Auto Finance             Direct      2024-08-02  2024-10-31
# 1        Bajaj Finance Auto             Online      2024-05-21  2024-10-31
# ...

# %%
df.head()
# Out:
#                LoanID        PoolID  BorrowerID ServicerID  \
# 0  ZAAUTO2024-1-00001  ZAAUTO2024-1  BOR-131244     SVC001
# 1  ZAAUTO2024-1-00002  ZAAUTO2024-1  BOR-748564     SVC003
# 2  ZAAUTO2024-1-00003  ZAAUTO2024-1  BOR-694731     SVC002
# 3  ZAAUTO2024-1-00004  ZAAUTO2024-1  BOR-855731     SVC003
# 4  ZAAUTO2024-1-00005  ZAAUTO2024-1  BOR-897549     SVC003
#
#              ServicerName OriginationChannel OriginationDate  CutoffDate  \
# 0  HDFC Bank Auto Finance             Direct      2024-08-02  2024-10-31
# 1      Bajaj Finance Auto             Online      2024-05-21  2024-10-31
# 2        ICICI Auto Loans             Online      2024-08-03  2024-10-31
# 3      Bajaj Finance Auto             Online      2023-05-15  2024-10-31
# 4      Bajaj Finance Auto             Online      2021-08-18  2024-10-31
#
#   MaturityDate  OriginalLoanAmount  ...  ECL_Provision  IsDefaulted  \
# 0   2031-06-27            782300.0  ...        7507.75        False
# ...

# %%
df.columns
# Out:
# Index(['LoanID', 'PoolID', 'BorrowerID', 'ServicerID', 'ServicerName',
#        'OriginationChannel', 'OriginationDate', 'CutoffDate', 'MaturityDate',
#        'OriginalLoanAmount', 'OriginalTerm', 'RemainingTerm', 'MonthsOnBook',
#        'InterestRate', 'MonthlyEMI', 'LoanPurpose', 'CurrentBalance',
#        'ScheduledPaymentDue', 'LastPaymentAmount', 'LastPaymentDate',
#        'DelinquencyStatus', 'DelinquencyDays', 'TotalPaymentsDue',
#        'TotalPaymentsMade', 'Times30DPD_Last12M', 'Times60DPD_Last12M',
#        'Times90DPD_Last12M', 'VehicleMake', 'VehicleModel', 'VehicleYear',
#        'VehicleType', 'IsNewVehicle', 'OriginalVehicleValue',
#        'CurrentVehicleValue', 'LTV_AtOrigination', 'LTV_Current',
#        'BorrowerAge', 'EmploymentType', 'AnnualIncome_INR', 'DTI_Ratio',
#        'CIBIL_Score_Origination', 'CIBIL_Score_Current', 'Region', 'State',
#        'IFRS9_Stage', 'PD_Estimate', 'LGD_Estimate', 'EAD', 'ECL_Provision',
# ...

# %%
df.isnull().sum()
# Out:
# LoanID                       0
# PoolID                       0
# BorrowerID                   0
# ServicerID                   0
# ServicerName                 0
# OriginationChannel           0
# OriginationDate              0
# CutoffDate                   0
# MaturityDate                 0
# OriginalLoanAmount           0
# OriginalTerm                 0
# RemainingTerm                0
# MonthsOnBook                 0
# InterestRate                 0
# MonthlyEMI                   0
# LoanPurpose                  0
# CurrentBalance               0
# ScheduledPaymentDue          0
# LastPaymentAmount            0
# LastPaymentDate              0
# DelinquencyStatus            0
# DelinquencyDays              0
# TotalPaymentsDue             0
# TotalPaymentsMade            0
# Times30DPD_Last12M           0
# Times60DPD_Last12M           0
# Times90DPD_Last12M           0
# VehicleMake                  0
# VehicleModel                 0
# VehicleYear                  0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["ModificationType"] = df["ModificationType"].fillna("No Modification")
df
# Out:
#                  LoanID        PoolID  BorrowerID ServicerID  \
# 0    ZAAUTO2024-1-00001  ZAAUTO2024-1  BOR-131244     SVC001
# 1    ZAAUTO2024-1-00002  ZAAUTO2024-1  BOR-748564     SVC003
# 2    ZAAUTO2024-1-00003  ZAAUTO2024-1  BOR-694731     SVC002
# 3    ZAAUTO2024-1-00004  ZAAUTO2024-1  BOR-855731     SVC003
# 4    ZAAUTO2024-1-00005  ZAAUTO2024-1  BOR-897549     SVC003
# ..                  ...           ...         ...        ...
# 495  ZAAUTO2024-1-00496  ZAAUTO2024-1  BOR-130294     SVC002
# 496  ZAAUTO2024-1-00497  ZAAUTO2024-1  BOR-208691     SVC003
# 497  ZAAUTO2024-1-00498  ZAAUTO2024-1  BOR-375903     SVC002
# 498  ZAAUTO2024-1-00499  ZAAUTO2024-1  BOR-366825     SVC003
# 499  ZAAUTO2024-1-00500  ZAAUTO2024-1  BOR-597793     SVC003
#
#                ServicerName OriginationChannel OriginationDate  CutoffDate  \
# 0    HDFC Bank Auto Finance             Direct      2024-08-02  2024-10-31
# 1        Bajaj Finance Auto             Online      2024-05-21  2024-10-31
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LoanID                   500 non-null    object
#  1   PoolID                   500 non-null    object
#  2   BorrowerID               500 non-null    object
#  3   ServicerID               500 non-null    object
#  4   ServicerName             500 non-null    object
#  5   OriginationChannel       500 non-null    object
#  6   OriginationDate          500 non-null    object
#  7   CutoffDate               500 non-null    object
#  8   MaturityDate             500 non-null    object
#  9   OriginalLoanAmount       500 non-null    float64
#  10  OriginalTerm             500 non-null    int64
#  11  RemainingTerm            500 non-null    int64
#  12  MonthsOnBook             500 non-null    int64
#  13  InterestRate             500 non-null    float64
# ...

# %%
date_columns = ["OriginationDate", "CutoffDate", "MaturityDate", "LastPaymentDate"]

for col in date_columns:
    df[col] = pd.to_datetime(df[col])
df
# Out:
#                  LoanID        PoolID  BorrowerID ServicerID  \
# 0    ZAAUTO2024-1-00001  ZAAUTO2024-1  BOR-131244     SVC001
# 1    ZAAUTO2024-1-00002  ZAAUTO2024-1  BOR-748564     SVC003
# 2    ZAAUTO2024-1-00003  ZAAUTO2024-1  BOR-694731     SVC002
# 3    ZAAUTO2024-1-00004  ZAAUTO2024-1  BOR-855731     SVC003
# 4    ZAAUTO2024-1-00005  ZAAUTO2024-1  BOR-897549     SVC003
# ..                  ...           ...         ...        ...
# 495  ZAAUTO2024-1-00496  ZAAUTO2024-1  BOR-130294     SVC002
# 496  ZAAUTO2024-1-00497  ZAAUTO2024-1  BOR-208691     SVC003
# 497  ZAAUTO2024-1-00498  ZAAUTO2024-1  BOR-375903     SVC002
# 498  ZAAUTO2024-1-00499  ZAAUTO2024-1  BOR-366825     SVC003
# 499  ZAAUTO2024-1-00500  ZAAUTO2024-1  BOR-597793     SVC003
#
#                ServicerName OriginationChannel OriginationDate CutoffDate  \
# 0    HDFC Bank Auto Finance             Direct      2024-08-02 2024-10-31
# 1        Bajaj Finance Auto             Online      2024-05-21 2024-10-31
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LoanID                   500 non-null    object
#  1   PoolID                   500 non-null    object
#  2   BorrowerID               500 non-null    object
#  3   ServicerID               500 non-null    object
#  4   ServicerName             500 non-null    object
#  5   OriginationChannel       500 non-null    object
#  6   OriginationDate          500 non-null    datetime64[ns]
#  7   CutoffDate               500 non-null    datetime64[ns]
#  8   MaturityDate             500 non-null    datetime64[ns]
#  9   OriginalLoanAmount       500 non-null    float64
#  10  OriginalTerm             500 non-null    int64
#  11  RemainingTerm            500 non-null    int64
#  12  MonthsOnBook             500 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["DelinquencyStatus"].value_counts()
# Out:
# DelinquencyStatus
# Current        385
# 1-29 DPD        37
# 60-89 DPD       24
# 30-59 DPD       21
# 120+ DPD        14
# 90-119 DPD      10
# Default          7
# Repossessed      2
# Name: count, dtype: int64

# %%
df["LoanPurpose"].value_counts()
# Out:
# LoanPurpose
# New Vehicle Purchase     419
# Used Vehicle Purchase     48
# Refinance                 33
# Name: count, dtype: int64

# %%
import os
print(os.getcwd())
# Out:
# /Users/kavyagodala

# %%
df.to_csv("cleaned_auto_loan_data.csv", index=False)
print("File Saved Successfully")
# Out:
# File Saved Successfully
